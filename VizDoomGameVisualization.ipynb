# %%
from vizdoom import *
import cv2
import numpy as np
import time
import random
from matplotlib import pyplot as plt
import pandas as pd

# Gym imports
import gymnasium as gym
from gymnasium import Env
from gymnasium.spaces import Discrete, Box

# %%
# Instantiate TakeCover environment
CONFIG_PATH = './github/ViZDoom/scenarios/take_cover.cfg'

# %%
# Create Vizdoom OpenAI Gym Environment
class VizDoomGym(Env): 
    def __init__(self, render=False): 
        # Setup the game 
        super().__init__()
        self.frame_skip = 4
        self.game = DoomGame()
        self.game.load_config(CONFIG_PATH)
        
        # Render frame logic
        self.game.set_window_visible(render)
        
        # Start the game 
        self.game.init()
        
        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8) 
        self.action_space = Discrete(2) # Move left, move right
        self._actions = np.eye(2, dtype=np.uint8)

        # Reward shaping parameters
        # Positve reward for staying alive, negative reward for getting hit
        self.game.set_living_reward(1.0)
        self.game.set_death_penalty(100.0)
        
    # This is how we take a step in the environment
    def step(self, action):
        # Specify action and take step 
        reward = self.game.make_action(self._actions[action].tolist(), self.frame_skip) 
        
        # Get the new state of the game and check if it's done
        if self.game.get_state(): 
            obs    = self._process_frame(self.game.get_state().screen_buffer)
            health = self.game.get_state().game_variables[0]
            info   = {"health": health}
        else: 
            obs = np.zeros(self.observation_space.shape, dtype=np.uint8)
            info = {"health": 0}
        
        terminated = self.game.is_episode_finished()
        truncated = False

        return obs, reward, terminated, truncated, info
    
    # Define how to render the game or environment 
    def render(self): 
        pass
    
    # Starting a new game 
    def reset(self, seed=None, options=None): 
        super().reset(seed=seed)
        self.game.new_episode()
        state = self.game.get_state()

        if state is not None:
            obs = self._process_frame(state.screen_buffer)
        else:
            obs = np.zeros(self.observation_space.shape, dtype=np.uint8)

        
        return obs, {}
    
    # Call to close down the game
    def close(self): 
        self.game.close()

    def _process_frame(self, buffer: np.ndarray):
        hwc  = np.moveaxis(buffer, 0, -1)                           
        gray = cv2.cvtColor(hwc, cv2.COLOR_RGB2GRAY)               
        resized = cv2.resize(gray, (160, 100), interpolation=cv2.INTER_CUBIC)
        clipped = np.clip(resized, 0, 255).astype(np.uint8)         
        return clipped.reshape(100, 160, 1)

# %%
env = VizDoomGym(render=False)
obs, _ = env.reset()

# %%
delta_y_values = []
delta_x_values = []
for _ in range(500):
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    
    # stampa i delta_x grezzi per calibrare le soglie
    state = env.game.get_state()
    if state:
        for label in state.labels:
            if label.object_name == "DoomImpBall":
                delta_x_values.append(-label.object_position_x)
                delta_y_values.append(label.object_position_y - state.game_variables[2])

    if terminated or truncated:
        obs, _ = env.reset()
        
# Evaluate results to determine good thresholds for urgency classification
max_delta_x = max(delta_x_values) 
threshold_imminent   = max_delta_x * 0.5 
threshold_approaching = max_delta_x

print(f"Suggested URGENCY_IMMINENT threshold: {threshold_imminent:.2f}")
print(f"Suggested URGENCY_APPROACHING threshold: {threshold_approaching:.2f}")
# Out:
# Suggested URGENCY_IMMINENT threshold: 199.92
# Suggested URGENCY_APPROACHING threshold: 399.83

# %%
class PerceptionLayer:
    URGENCY_IMMINENT   =  200
    URGENCY_APPROACHING = 400
    SIDE_THRESHOLD = 30 

    ACTION_NAMES = {0: "move_left", 1: "move_right"}

    def __init__(self):
        self.prev_health  = 100
        self.last_action  = None
        self.step_count   = 0

    def reset(self):
        self.prev_health = 100
        self.last_action = None
        self.step_count  = 0

    def update(self, state, action):
        self.step_count += 1
        self.last_action = action

        player_y, health, delta_h = self._get_player_state(state)
        projectiles = self._get_projectiles(state, player_y)

        return self._serialize(player_y, health, delta_h, projectiles)
    
    def _get_player_state(self, state):
        vars = state.game_variables
        health = vars[0]
        player_y = vars[2]

        delta_h = health - self.prev_health
        self.prev_health = health

        return player_y, health, delta_h
    
    def _get_projectiles(self, state, player_y):
        projectiles = []
        for label in state.labels:
            if label.object_name == "DoomImpBall":
                delta_y = label.object_position_y - player_y
                delta_x = label.object_position_x
                projectiles.append({
                "delta_y": delta_y,
                "delta_x": delta_x,
                "side":    self._side(delta_y),
                "urgency": self._urgency(delta_x),
                })
        
        # Returns projectiles sorted by urgency (closest to player first)
        return sorted(projectiles, key=lambda p: abs(p["delta_x"]))
    
    def _side(self, delta_y: float) -> str:
        if abs(delta_y) < self.SIDE_THRESHOLD:
            return "center"
        return "left" if delta_y < 0 else "right"

    def _urgency(self, delta_x: float) -> str:
        dist = abs(delta_x)
        if dist < self.URGENCY_IMMINENT:
            return "imminent"
        elif dist < self.URGENCY_APPROACHING:
            return "approaching"
        return "distant"
    
    def _serialize(self, player_y, health, delta_h, projectiles) -> str:
        lines = []
        lines.append(f"Health: {int(health)}/100" + (f" (lost {abs(int(delta_h))} HP this step)" if delta_h < 0 else ""))
        lines.append(f"Player position: {self._side(player_y)}")
        lines.append(f"Last action: {self.ACTION_NAMES.get(self.last_action, 'none')}")
        lines.append(f"Survived: {self.step_count} steps")

        if not projectiles:
            lines.append("No projectiles visible.")
        else:
            lines.append(f"{len(projectiles)} projectile(s) detected:")
            for i, p in enumerate(projectiles, 1):
                lines.append(f"  {i}. {p['urgency'].upper()} threat on the {p['side']} side")

        return "\n".join(lines)

# %%
env = VizDoomGym(render=True)
perception = PerceptionLayer()

obs, info = env.reset()
perception.reset()

# %%
episodes = 1
for episode in range(episodes):
    terminated = False
    while not terminated:
        state = env.game.get_state()
        action = random.choice([0, 1])  # Randomly choose to move left or right

        state_text = perception.update(state, action)

        print(state_text)

        obs, reward, terminated, truncated, info = env.step(action)
        time.sleep(0.1)
    time.sleep(2)
# Out:
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 1 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 2 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 3 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 4 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 5 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 6 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 7 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 8 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 9 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 10 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 11 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 12 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 13 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 14 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 15 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 16 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 17 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 18 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the center side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 19 steps
# 1 projectile(s) detected:
#   1. APPROACHING threat on the center side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 20 steps
# 1 projectile(s) detected:
#   1. APPROACHING threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 21 steps
# 1 projectile(s) detected:
#   1. APPROACHING threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 22 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 23 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 24 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 25 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 26 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 27 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 28 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 29 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the center side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 30 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the center side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 31 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the center side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 32 steps
# 1 projectile(s) detected:
#   1. APPROACHING threat on the center side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 33 steps
# 1 projectile(s) detected:
#   1. APPROACHING threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 34 steps
# 1 projectile(s) detected:
#   1. APPROACHING threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 35 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 36 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 37 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 38 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 39 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 40 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 41 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 42 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 43 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 44 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 45 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 46 steps
# 2 projectile(s) detected:
#   1. IMMINENT threat on the right side
#   2. IMMINENT threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 47 steps
# 2 projectile(s) detected:
#   1. IMMINENT threat on the right side
#   2. IMMINENT threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 48 steps
# 3 projectile(s) detected:
#   1. IMMINENT threat on the right side
#   2. IMMINENT threat on the right side
#   3. IMMINENT threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 49 steps
# 3 projectile(s) detected:
#   1. IMMINENT threat on the right side
#   2. IMMINENT threat on the right side
#   3. IMMINENT threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 50 steps
# 3 projectile(s) detected:
#   1. IMMINENT threat on the right side
#   2. IMMINENT threat on the right side
#   3. APPROACHING threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 51 steps
# 3 projectile(s) detected:
#   1. IMMINENT threat on the center side
#   2. IMMINENT threat on the right side
#   3. APPROACHING threat on the center side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 52 steps
# 3 projectile(s) detected:
#   1. IMMINENT threat on the center side
#   2. APPROACHING threat on the right side
#   3. APPROACHING threat on the center side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 53 steps
# 3 projectile(s) detected:
#   1. APPROACHING threat on the right side
#   2. APPROACHING threat on the left side
#   3. APPROACHING threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 54 steps
# 3 projectile(s) detected:
#   1. APPROACHING threat on the right side
#   2. APPROACHING threat on the left side
#   3. APPROACHING threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 55 steps
# 2 projectile(s) detected:
#   1. APPROACHING threat on the right side
#   2. APPROACHING threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 56 steps
# 1 projectile(s) detected:
#   1. APPROACHING threat on the center side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 57 steps
# 1 projectile(s) detected:
#   1. APPROACHING threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 58 steps
# 1 projectile(s) detected:
#   1. APPROACHING threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 59 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 60 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 61 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 62 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 63 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 64 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 65 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 66 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 67 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 68 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 69 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 70 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 71 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 72 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 73 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 74 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 75 steps
# 1 projectile(s) detected:
#   1. IMMINENT threat on the center side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 76 steps
# 1 projectile(s) detected:
#   1. APPROACHING threat on the center side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 77 steps
# 1 projectile(s) detected:
#   1. APPROACHING threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 78 steps
# 1 projectile(s) detected:
#   1. APPROACHING threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 79 steps
# 1 projectile(s) detected:
#   1. APPROACHING threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 80 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 81 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 82 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 83 steps
# No projectiles visible.
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 84 steps
# 2 projectile(s) detected:
#   1. IMMINENT threat on the right side
#   2. IMMINENT threat on the left side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 85 steps
# 2 projectile(s) detected:
#   1. IMMINENT threat on the left side
#   2. IMMINENT threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 86 steps
# 2 projectile(s) detected:
#   1. IMMINENT threat on the left side
#   2. IMMINENT threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 87 steps
# 2 projectile(s) detected:
#   1. IMMINENT threat on the left side
#   2. IMMINENT threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 88 steps
# 2 projectile(s) detected:
#   1. IMMINENT threat on the left side
#   2. IMMINENT threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 89 steps
# 3 projectile(s) detected:
#   1. IMMINENT threat on the left side
#   2. IMMINENT threat on the left side
#   3. IMMINENT threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 90 steps
# 3 projectile(s) detected:
#   1. IMMINENT threat on the left side
#   2. IMMINENT threat on the left side
#   3. APPROACHING threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 91 steps
# 3 projectile(s) detected:
#   1. IMMINENT threat on the left side
#   2. APPROACHING threat on the left side
#   3. APPROACHING threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 92 steps
# 3 projectile(s) detected:
#   1. IMMINENT threat on the left side
#   2. APPROACHING threat on the left side
#   3. APPROACHING threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 93 steps
# 3 projectile(s) detected:
#   1. IMMINENT threat on the left side
#   2. APPROACHING threat on the left side
#   3. APPROACHING threat on the right side
# Health: 100/100
# Player position: right
# Last action: move_right
# Survived: 94 steps
# 3 projectile(s) detected:
#   1. IMMINENT threat on the left side
#   2. APPROACHING threat on the left side
#   3. APPROACHING threat on the center side
# Health: 100/100
# Player position: right
# Last action: move_left
# Survived: 95 steps
# 3 projectile(s) detected:
#   1. IMMINENT threat on the left side
#   2. APPROACHING threat on the center side
#   3. APPROACHING threat on the center side

# %%
env.close()
# Out:
# *** Fatal Error ***
# Address not mapped to object (signal 11)
# Address: 0x7fa45db95f28
#
# Generating vizdoom-crash.log and killing process 98780, please wait... sh: 1: gdb: not found
# Warning: Missing charsets in String to FontSet conversion
